# %%
import cv2
import numpy as np
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-bd2cdcd9500e> in <module>()
# ----> 1 import cv2
#       2 import numpy as np
#
# ImportError: No module named cv2

# %%
import os
os.sys.path
import cv2
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-2-076592ec21bc> in <module>()
#       1 import os
#       2 os.sys.path
# ----> 3 import cv2
#
# ImportError: No module named cv2

# %%
import os

# %%
os.sys.path
# Out:
# ['',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\python27.zip',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\DLLs',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib\\plat-win',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib\\lib-tk',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib\\site-packages',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib\\site-packages\\win32',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Nick\\AppData\\Local\\Continuum\\anaconda2\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Nick\\.ipython']

# %%
import cv2
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-5-c8ec22b3e787> in <module>()
# ----> 1 import cv2
#
# ImportError: No module named cv2

# %%
import  cv2
# Out:
#   File "<ipython-input-6-b70bc830242d>", line 1
#     import  C:\Python27\Lib\site-packages\cv2
#              ^
# SyntaxError: invalid syntax

# %%
import sys
sys.path.append('C:\Python27\Lib\site-packages\')
# Out:
#   File "<ipython-input-7-def741c66249>", line 2
#     sys.path.append('C:\Python27\Lib\site-packages\')
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
import sys
sys.path.append('C:\Python27\Lib\site-packages')

# %%
import  cv2

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
img = cv2.imread('download.jpg',0)
edges = cv2.Canny(img,100,200)

# %%
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-13-9cfa37f52ac1> in <module>()
# ----> 1 plt.subplot(121),plt.imshow(img,cmap = 'gray')
#       2 plt.title('Original Image'), plt.xticks([]), plt.yticks([])
#       3 plt.subplot(122),plt.imshow(edges,cmap = 'gray')
#       4 plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5485                               resample=resample, **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     647         if (self._A.dtype != np.uint8 and
#     648                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 649             raise TypeError("Image data cannot be converted to float")
#     650
#     651         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
plt.show()

# %%
plt.subplot(121),plt.imshow(img,cmap = 'gray'
# Out:
#   File "<ipython-input-15-ae4e9f352367>", line 1
#     plt.subplot(121),plt.imshow(img,cmap = 'gray'
#                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
img = cv2.imread('messi5.jpg',0)
edges = cv2.Canny(img,100,200)

# %%
plt.subplot(121),plt.imshow(img,cmap = 'gray')
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-17-571552afbd5c> in <module>()
# ----> 1 plt.subplot(121),plt.imshow(img,cmap = 'gray')
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5485                               resample=resample, **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# C:\Users\Nick\AppData\Local\Continuum\anaconda2\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     647         if (self._A.dtype != np.uint8 and
#     648                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 649             raise TypeError("Image data cannot be converted to float")
#     650
#     651         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
img = cv2.imread('download.jpg',0)
edges = cv2.Canny(img,100,200)

# %%
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'Edge Image'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.show()

# %%
import sys
sys.path.append('C:\Python27\Lib\site-packages')

# %%
import  cv2

# %%
import sys
sys.path.append('C:\Python27\Lib\site-packages')

import  cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('download.jpg',0)
edges = cv2.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
